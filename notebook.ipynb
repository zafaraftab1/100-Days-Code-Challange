# %%
from unicodedata import lookup

#Sorts a list and then rearranges it to move all zero values to the beginning while keeping non-zero elements after them.

mylist=[1,2,54,3,0, 4,0,5,0]
# method 1
mylist.sort()
print(mylist)

# method 2
newlist=[x for x in mylist if x==0] + [x for x in mylist if x!=0]
print(newlist)

# %%
#Two Sum Problem
#Given a list of integers and a target number, return the indices of the two numbers that add up to the target.

def two_sum(nums, target):
    lookup={}
    for i, num in enumerate(nums):
        complement=target-num
        if complement in lookup:
            return [lookup[complement], i]
        lookup[num]=i
    return None

nums=[2,7,11,15]
target=9
result=two_sum(nums, target)
print(result)
# Out:
# [0, 1]
