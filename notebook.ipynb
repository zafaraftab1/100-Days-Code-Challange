# %%
mylist=[1,2,54,3,0, 4,0,5,0]
# method 1
mylist.sort()
print(mylist)

# method 2
newlist=[x for x in mylist if x==0] + [x for x in mylist if x!=0]
print(newlist)
# Out:
# [0, 0, 0, 1, 2, 3, 4, 5, 54]
# [0, 0, 0, 1, 2, 3, 4, 5, 54]
